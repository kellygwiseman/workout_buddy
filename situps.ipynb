# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Plotting Functions

# %%
# Set up some better defaults for matplotlib
import brewer2mpl
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_colors = brewer2mpl.get_map('Dark2', 'Qualitative', 7).mpl_colors

rcParams['figure.figsize'] = (8, 4)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 1.5
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'

# %%
def plot3_acceleration(data, freq):
    time = data.index.values / freq
    fig1 = plt.figure()
    plt.plot(time, data.accelerometerAccelerationX)
    plt.title('X-component Acceleration')
    plt.xlabel('Time (seconds)')
    plt.xlim(0,time[-1])
    fig2 = plt.figure()
    plt.plot(time, data.accelerometerAccelerationY)
    plt.title('X-component Acceleration')
    plt.xlabel('Time (seconds)')
    plt.xlim(0,time[-1])
    fig3 = plt.figure()
    plt.plot(time, data.accelerometerAccelerationZ)
    plt.xlabel('Time (seconds)')
    plt.xlim(0,time[-1])
    plt.title('X-component Acceleration');
    
def plot1_acceleration(data, freq, sample):
    time = data.index.values / freq
    fig1 = plt.figure()
    plt.plot(time, data.accelerometerAccelerationX, label='X' )
    plt.plot(time, data.accelerometerAccelerationY, label='Y')
    plt.plot(time, data.accelerometerAccelerationZ, label='Z')
    plt.title('Acceleration')
    plt.xlabel('Time (Seconds)')
    plt.ylabel('Meter / Second^2 (in G)')
    plt.xlim(0,time[-1])
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1)
    plt.savefig('su_accel-'+sample+'.png');
    
def plot1_Uacceleration(data, freq, sample):
    time = data.index.values / freq
    fig1 = plt.figure()
    plt.plot(time, data.motionUserAccelerationX, label='X' )
    plt.plot(time, data.motionUserAccelerationY, label='Y')
    plt.plot(time, data.motionUserAccelerationZ, label='Z')
    plt.title('User Acceleration')
    plt.xlabel('Time (Seconds)')
    plt.ylabel('Meter / Second^2 (in G)')
    plt.xlim(0,time[-1])
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1)
    plt.savefig('su_Uaccel-'+sample+'.png');

def plot1_gyro(data, freq, sample):
    time = data.index.values / freq
    fig1 = plt.figure()
    plt.plot(time, data.gyroRotationX, label='X')
    plt.plot(time, data.gyroRotationY, label='Y')
    plt.plot(time, data.gyroRotationZ, label='Z')
    plt.title('Gyro Rotation')
    plt.xlabel('Time (Seconds)')
    plt.ylabel('Radians / Second')
    plt.xlim(0,time[-1])
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1)
    plt.savefig('su_gyro-'+sample+'.png');
    
def plot1_motion(data, freq, sample):
    time = data.index.values / freq
    fig1 = plt.figure()
    plt.plot(time, data.motionPitch, label='Pitch')
    plt.plot(time, data.motionRoll, label='Roll')
    plt.plot(time, data.motionYaw, label='Yaw')
    plt.title('Phone Attitude')
    plt.xlabel('Time (Seconds)')
    plt.ylabel('Radians')
    plt.xlim(0,time[-1])
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1)
    plt.savefig('su_attitude-'+sample+'.png');

def plot_corr(data, correls, freq, sample):
    time = data.index.values / freq
    fig1 = plt.figure()
    plt.plot(time, correls.ix[:, 'accelerometerAccelerationX', 'accelerometerAccelerationY'], label='X-Y')
    plt.plot(time, correls.ix[:, 'accelerometerAccelerationX', 'accelerometerAccelerationZ'], label='X-Z')
    plt.plot(time, correls.ix[:, 'accelerometerAccelerationY', 'accelerometerAccelerationZ'], label='Y-Z')
    plt.title('Acceleration Feature Correlation')
    plt.xlabel('Time (Seconds)')
    plt.ylabel('Correlation Coefficient')
    plt.xlim(0,time[-1])
    plt.ylim(-1.5,1.25)
    plt.yticks(np.arange(-1.0,1.5,0.5))
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1)
    plt.savefig('su_corr_acc-'+sample+'.png');
    fig2 = plt.figure()
    plt.plot(time, correls.ix[:, 'gyroRotationX', 'gyroRotationY'], label='X-Y')
    plt.plot(time, correls.ix[:, 'gyroRotationX', 'gyroRotationZ'], label='X-Z')
    plt.plot(time, correls.ix[:, 'gyroRotationY', 'gyroRotationZ'], label='Y-Z')
    plt.title('Gyro Feature Correlation')
    plt.xlabel('Time (Seconds)')
    plt.ylabel('Correlation Coefficient')
    plt.xlim(0,time[-1])
    plt.ylim(-1.5,1.25)
    plt.yticks(np.arange(-1.0,1.5,0.5))
    plt.savefig('su_corr_gyro-'+sample+'.png')
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1);
    fig3 = plt.figure()
    plt.plot(time, correls.ix[:, 'motionPitch', 'motionRoll'], label='Pitch-Roll')
    plt.plot(time, correls.ix[:, 'motionPitch', 'motionYaw'], label='Pitch-Yaw')
    plt.plot(time, correls.ix[:, 'motionRoll', 'motionYaw'], label='Roll-Yaw')
    plt.title('Attitude Feature Correlation')
    plt.xlabel('Time (Seconds)')
    plt.ylabel('Correlation Coefficient')
    plt.xlim(0,time[-1])
    plt.ylim(-1.5,1.25)
    plt.yticks(np.arange(-1.0,1.5,0.5))
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1)
    plt.savefig('su_corr_att-'+sample+'.png');

def plot_siyups(data, situp_window, widths, freq, sample):
    time = data.index.values / freq
    situp_start = situp_window.index[0] / freq
    situp_time = situp_window.index.values / freq
    
    # calculate sit-up reps
    
    peakind = signal.find_peaks_cwt(situp_window['motionPitch'], widths)
    peakind = [x / freq for x in peakind]
    
    # Plot complete time series and sit-up duration overlay
    fig1 = plt.figure()
    plt.plot(time, data.motionPitch, label='Raw data')
    plt.plot(situp_time, situp_window['motionPitch'], label='Sit-up duration')
    
    # Plot sit-ups
    plt.scatter(situp_start + peakind,np.linspace(0.0,0.0,num=len(peakind)), color='r',marker='x', lw=2, label='Sit-ups')
    plt.title('Sit-up Repetitions')
    plt.ylabel('Pitch (Radians)')
    plt.xlabel('Time (Seconds)')
    plt.xlim(0,time[-1])
    plt.ylim(-0.5, 1.6)
    plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.0), frameon=False, columnspacing=1, borderpad=0.1)
    plt.savefig('su_reps-'+sample+'.png')
    return peakind;

# %% [markdown]
# # arms back situps

# %%
df = pd.read_csv('phone_data.csv', names=indexes)
plot1_acceleration(df, 20.0)

# %%
# 20 Hz data
indexes = [u'loggingTime', u'loggingSample', u'locationTimestamp_since1970', u'locationLatitude', u'locationLongitude', u'locationAltitude', u'locationSpeed', u'locationCourse', u'locationVerticalAccuracy', u'locationHorizontalAccuracy', u'locationFloor', u'locationHeadingTimestamp_since1970', u'locationHeadingX', u'locationHeadingY', u'locationHeadingZ', u'locationTrueHeading', u'locationMagneticHeading', u'locationHeadingAccuracy', u'accelerometerTimestamp_sinceReboot', u'accelerometerAccelerationX', u'accelerometerAccelerationY', u'accelerometerAccelerationZ', u'gyroTimestamp_sinceReboot', u'gyroRotationX', u'gyroRotationY', u'gyroRotationZ', u'motionTimestamp_sinceReboot', u'motionYaw', u'motionRoll', u'motionPitch', u'motionRotationRateX', u'motionRotationRateY', u'motionRotationRateZ', u'motionUserAccelerationX', u'motionUserAccelerationY', u'motionUserAccelerationZ', u'motionAttitudeReferenceFrame', u'motionQuaternionX', u'motionQuaternionY', u'motionQuaternionZ', u'motionQuaternionW', u'motionGravityX', u'motionGravityY', u'motionGravityZ', u'motionMagneticFieldX', u'motionMagneticFieldY', u'motionMagneticFieldZ', u'motionMagneticFieldCalibrationAccuracy', u'IP_en0', u'IP_pdp_ip0', u'deviceOrientation', u'state']
#df = pd.read_csv('data/sensor/2015-02-21_18-55-31.csv')
df = pd.read_csv('my_data.csv', names=indexes)
numeric_features = ['accelerometerAccelerationX','accelerometerAccelerationY','accelerometerAccelerationZ',
            'gyroRotationX','gyroRotationY','gyroRotationZ',
            'motionYaw','motionRoll','motionPitch']
df_num = df[numeric_features]

# %%
df_num.head()
# Out:
#    accelerometerAccelerationX  accelerometerAccelerationY  \
# 0                    0.037521                   -0.636490
# 1                    0.007812                   -0.623947
# 2                    0.000656                   -0.617889
# 3                   -0.027527                   -0.591080
# 4                   -0.002167                   -0.608078
#
#    accelerometerAccelerationZ  gyroRotationX  gyroRotationY  gyroRotationZ  \
# 0                   -0.754593       0.013526      -0.007824      -0.049979
# 1                   -0.785599       0.020825       0.015692       0.070512
# 2                   -0.762512       0.020825       0.015692       0.070512
# 3                   -0.825623      -0.003218      -0.068961       0.072692
# 4                   -0.760574      -0.003218      -0.068961       0.072692
#
#    motionYaw  motionRoll  motionPitch
# 0  -0.566026   -0.027840     0.650296
# 1  -0.570299   -0.025245     0.652999
# 2  -0.568107   -0.023667     0.655512
# ...

# %%
plot1_acceleration(df_num, 20.0)
#plot1_acceleration(df2_num, 20.0)
plot1_gyro(df_num, 20.0)
#plot1_gyro(df2_num, 20.0)
plot1_motion(df_num, 20.0)
#plot1_motion(df2_num, 20.0)

# %% [markdown]
# I think the large yaw correlated with the mini pitch peaks might be due to moving arms in during situps

# %% [markdown]
# # Sit-up identification and counting algorithm

# %%
# look at correlation between features
correls = pd.rolling_corr(df_num, 50)
correls2 = pd.rolling_corr(df2_num, 50)
plot_corr(df_num, correls, 20.0)
plot_corr(df2_num, correls2, 20.0)

# %%
from scipy import signal
#cond1 = correls.ix[:, 'gyroRotationY', 'gyroRotationZ'] < -0.5
cond1 = correls2.ix[:, 'gyroRotationX', 'gyroRotationY'] > 0.25
#cond2 = correls.ix[:, 'motionRoll', 'motionYaw'] < -0.7
cond2 = correls2.ix[:, 'motionRoll', 'motionPitch'] > 0.25
cond3 = correls.ix[:, 'accelerometerAccelerationX', 'accelerometerAccelerationZ'] > 0.5
su_window = df2_num[cond1 & cond2]
su_start = su_window.index[0]
widths = np.arange(8,12)
peakind = signal.find_peaks_cwt(su_window['motionPitch'], widths)

print peakind
print 'number of sit-ups = ', len(peakind)

# plot sit-ups

df2_num['motionPitch'].plot()
su_window['motionPitch'].plot()
plt.xlabel('Frequency (20 Hz)')
plt.ylabel('Pitch')
plt.scatter(su_start + peakind,np.linspace(0.0,0.0,num=len(peakind)),
            color='r', marker='x', lw=2);
# Out:
# [77, 128, 180, 230, 282, 337, 389, 446, 501]
# number of sit-ups =  9

# %% [markdown]
# # Arms crossed sit-ups

# %%
# 20 Hz data
ip5_csu = pd.read_csv('data/sensor/2015-02-21_11-26-23_csu.csv')

# %%
fig1 = plt.figure()
ip5_csu.accelerometerAccelerationX.plot()
plt.title('Acceleration X')
fig2 = plt.figure()
ip5_csu.accelerometerAccelerationY.plot()
plt.title('Acceleration Y')
fig3 = plt.figure()
ip5_csu.accelerometerAccelerationZ.plot()
plt.title('Acceleration Z');

# %%
fig1 = plt.figure()
ip5_csu.gyroRotationX.plot()
plt.title('GYRO X')
fig2 = plt.figure()
ip5_csu.gyroRotationY.plot()
plt.title('GYRO Y')
fig3 = plt.figure()
ip5_csu.gyroRotationZ.plot()
plt.title('GYRO Z');

# %%
fig1 = plt.figure()
ip5_csu.motionYaw.plot()
plt.title('Yaw')
fig2 = plt.figure()
ip5_csu.motionRoll.plot()
plt.title('Roll')
fig3 = plt.figure()
ip5_csu.motionPitch.plot()
plt.title('Pitch');

# %%
# look at correlation between features
features = ['accelerometerAccelerationX','accelerometerAccelerationY','accelerometerAccelerationZ',
                       'gyroRotationX','gyroRotationY','gyroRotationZ','motionYaw','motionRoll','motionPitch']
ip5_csu_num = ip5_csu[features]
correls = pd.rolling_corr(ip5_csu_num, 50)
correls.ix[:, 'gyroRotationX', 'gyroRotationZ'].plot()
correls.ix[:, 'gyroRotationX', 'gyroRotationY'].plot()
correls.ix[:, 'motionYaw', 'motionPitch'].plot()
correls.ix[:, 'accelerometerAccelerationY', 'accelerometerAccelerationZ'].plot();

# %%
from scipy import signal
cond1 = correls.ix[:, 'gyroRotationX', 'gyroRotationZ'] < -0.7
cond2 = correls.ix[:, 'motionYaw', 'motionPitch'] > 0.5
#cond3 = correls.ix[:, 'accelerometerAccelerationX', 'accelerometerAccelerationZ'] > 0.3
su_window = ip5_csu_num[cond1 & cond2]
su_start = su_window.index[0]
ip5_csu_num['motionPitch'].plot()
su_window['motionPitch'].plot()
#push_window['motionYaw'].plot()
widths = np.arange(8,10)
peakind = signal.find_peaks_cwt(su_window['motionPitch'], widths)
plt.scatter(su_start + peakind,np.linspace(0.0,0.0,num=len(peakind)), color='r')
print peakind
print 'number of sit-ups = ', len(peakind)
# Out:
# [6, 53, 100, 147, 194, 240, 299, 342, 386, 430]
# number of sit-ups =  10
