# %%
import sys
sys.path.append(r'../code')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import graphs as gr
from filter import filter_features
from detect_peaks import count_peaks, average_amplitude, average_duration
from matplotlib import rcParams
from dtw import *
from scipy import signal
# %matplotlib inline

# %% [markdown]
# ## Load the data

# %%
info = pd.read_csv('../data/pushup_info.csv', skipinitialspace=True)
info['file'] = info['timestamp'].copy()
info['timestamp'] = pd.to_datetime(info['timestamp'],format='%Y-%m-%d_%H-%M-%S')
info.head(2)
# Out:
#    user_id           timestamp  name exercise  hertz  count phone  stance  \
# 0        1 2015-02-21 12:35:35  Tali   pushup     20     10   ip5  normal
# 1        2 2015-02-21 18:55:31  Jess   pushup     20     10   ip5  normal
#
#    height (inches)  female form                     comments  \
# 0               66       1   ok     did not go down very far
# 1               64       1   ok  did not go down all the way
#
#                   file
# 0  2015-02-21_12-35-35
# 1  2015-02-21_18-55-31

# %% [markdown]
# ## Choose samples

# %%
# All
data_processed = info.copy()
data_processed.drop(['phone','comments'], axis=1, inplace=True)

# Normal stance samples
#cond1 = info['stance'] == 'normal'
#cond2 = info['hertz'] == 20
#data_info = info[cond1&cond2].drop(['phone','comments'], axis=1)

# Narrow stance samples
#cond1 = info['stance'] == 'narrow'
#cond2 = info['hertz'] == 20
#data_info = info[cond1&cond2].drop(['phone','comments'], axis=1)

# add columns
data_processed['Pcount'] = 0
data_processed['avg_amp'] = 0.0
data_processed['avg_dur'] = 0.0
data_processed.head(2)
# Out:
#    user_id           timestamp  name exercise  hertz  count  stance  \
# 0        1 2015-02-21 12:35:35  Tali   pushup     20     10  normal
# 1        2 2015-02-21 18:55:31  Jess   pushup     20     10  normal
#
#    height (inches)  female form                 file  Pcount  avg_amp  avg_dur
# 0               66       1   ok  2015-02-21_12-35-35       0        0        0
# 1               64       1   ok  2015-02-21_18-55-31       0        0        0

# %% [markdown]
# ## Batch Process the Samples

# %%
# Data info
numeric_features = ['motionUserAccelerationX', 'motionUserAccelerationY', 'motionUserAccelerationZ',
                    'motionRotationRateX', 'motionRotationRateY', 'motionRotationRateZ',
                    'accelerometerAccelerationX','accelerometerAccelerationY','accelerometerAccelerationZ',
                    'gyroRotationX','gyroRotationY','gyroRotationZ','motionYaw','motionRoll','motionPitch',
                    'motionQuaternionX','motionQuaternionY','motionQuaternionZ','motionQuaternionW']

# Iterate through all the samples
for i in xrange(data_processed.shape[0]):
    df = pd.read_csv('../data/sensor/'+data_processed.loc[i,'file']+'.csv')
    print '../data/sensor/'+data_processed.loc[i,'file']+'.csv'
    sample = data_processed.loc[i,'name']+'_'+data_processed.loc[i,'stance']
    female = data_processed.loc[i,'female']
    freq = data_processed.loc[i,'hertz']
    df_num = df[numeric_features]
    
    ## Plot raw data ##
    #gr.plot1_acceleration(df_num, freq, sample)
    #gr.plot1_gyro(df_num, freq, sample)
    #gr.plot1_motion(df_num, freq, sample)
    #gr.plot1_quaternion(df_num, freq, sample)
    
    ## Filter the data to separate the noise from the pushup signal ##
    # Bandpass filter
    lowcut = 0.5
    highcut =2.0
    order = 1
    df_filt = filter_features(df_num, numeric_features, lowcut, highcut, freq, order)
    # Plot
    #gr.plot_bandpass(df_num, df_filt, freq, lowcut, highcut, sample)
    
    # Look at feature correlations
    rolling_window = 30
    correls = pd.rolling_corr(df_filt, rolling_window)
    # Plot
    #gr.plot_corr(df_filt, correls, freq, sample)
    
    # Filter based on feature amplitudes
    cond1 = np.abs(correls.ix[:, 'accelerometerAccelerationX', 'accelerometerAccelerationY']) > 0.6
    cond2 = (np.abs(correls.ix[:, 'motionQuaternionY', 'motionQuaternionW'])+
             np.abs(correls.ix[:, 'motionQuaternionX', 'motionQuaternionY'])+
             np.abs(correls.ix[:, 'motionQuaternionY', 'motionQuaternionZ'])+
             np.abs(correls.ix[:, 'gyroRotationX', 'gyroRotationZ'])) > 2.5
    # Trim the beginning 3 seconds and last 2 seconds of record
    cond3 = df_filt.index > int(freq*2.5) 
    cond4 = df_filt.index < (df_filt.shape[0] - int(freq)) 
    
    # Pushup repetition window
    pushup_window = df_filt[cond1 & cond2 & cond3 & cond4].index
    pushup_data = df_filt.ix[pushup_window[0]:pushup_window[-1]]
    
    ## Count the number of repetitions ##
    # Peak parameters
    mph=(0.2 - 0.025*female) # minimum peak height
    mpd=0.5*freq + 0.25*freq*female # minimum peak separation distance
    feature = 'motionPitch'
    
    #mph=(0.12 - 0.025*female) # minimum peak height
    #mpd=10 + 5*female # minimum peak separation distance
    #feature = 'motionQuaternionY'
    peakind, count = count_peaks(df_filt, pushup_window, feature, mph, mpd, freq)
    avg_amp = average_amplitude(df_filt, peakind, pushup_window, feature, freq)
    avg_dur = average_duration(peakind, count)
    # Plot
    #gr.plot_pushups(df_filt, pushup_window, peakind, feature, freq, sample)
    
    # add results to dataframe
    data_processed.loc[i, 'Pcount'] = count
    data_processed.loc[i, 'avg_amp'] = avg_amp
    data_processed.loc[i, 'avg_dur'] = avg_dur
    
# write processed data to csv file
data_processed.drop('file',axis=1, inplace=True)
data_processed.to_csv('../processed/processed_pushup.csv')
# Out:
# ../data/sensor/2015-02-21_12-35-35.csv
# ../data/sensor/2015-02-21_18-55-31.csv
# ../data/sensor/2015-02-21_18-57-33.csv
# ../data/sensor/2015-02-21_18-59-09.csv
# ../data/sensor/2015-02-21_19-00-14.csv
# ../data/sensor/2015-02-21_11-24-43.csv
# ../data/sensor/2015-02-28_14-12-17.csv
# ../data/sensor/2015-02-28_14-13-46.csv
# ../data/sensor/2015-03-03_08-11-21.csv
# ../data/sensor/2015-03-03_08-09-39.csv
# ../data/sensor/2015-03-04_08-04-10.csv
# ../data/sensor/2015-03-04_08-05-28.csv
# ../data/sensor/2015-02-16_17-18-38.csv
# ../data/sensor/2015-02-16_17-20-25.csv
# ../data/sensor/2015-03-01_09-53-05.csv
# ../data/sensor/2015-03-01_09-53-39.csv
# ../data/sensor/2015-03-01_17-30-48.csv
# ../data/sensor/2015-03-03_19-56-55.csv
# ../data/sensor/2015-03-03_19-57-56.csv
# ../data/sensor/2015-02-26_20-00-15.csv
# ../data/sensor/2015-02-26_19-56-20.csv
# ../data/sensor/2015-02-26_19-53-19.csv
# ../data/sensor/2015-02-27_20-26-10.csv
# ../data/sensor/2015-02-27_20-20-03.csv
# ../data/sensor/2015-02-27_20-21-57.csv
# ../data/sensor/2015-02-27_17-08-09.csv
# ../data/sensor/2015-02-27_17-07-32.csv
# ../data/sensor/2015-02-27_17-02-15.csv
# ../data/sensor/2015-02-27_16-59-47.csv
# ../data/sensor/2015-02-27_16-57-09.csv
# ../data/sensor/2015-02-27_16-53-56.csv
# ../data/sensor/2015-02-27_16-45-36.csv
# ../data/sensor/2015-02-28_15-59-20.csv
# ../data/sensor/2015-03-01_11-11-36.csv
# ../data/sensor/2015-03-01_11-13-22.csv
# ../data/sensor/2015-03-01_11-13-51.csv
# ../data/sensor/2015-03-01_20-03-15.csv
# ../data/sensor/2015-03-01_20-03-47.csv
# ../data/sensor/2015-03-01_20-10-12.csv
# ../data/sensor/2015-03-01_20-10-35.csv
# ../data/sensor/2015-03-03_19-42-06.csv
# ../data/sensor/2015-03-03_19-42-47.csv

# %% [markdown]
# ## Look at Individual Samples

# %%
data_processed.head(45)
# Out:
#     user_id           timestamp     name exercise  hertz  count  stance  \
# 0         1 2015-02-21 12:35:35     Tali   pushup     20     10  normal
# 1         2 2015-02-21 18:55:31     Jess   pushup     20     10  normal
# 2         3 2015-02-21 18:57:33      Sam   pushup     20     10  normal
# 3         4 2015-02-21 18:59:09     Nick   pushup     20     10  normal
# 4         5 2015-02-21 19:00:14  JustinS   pushup     20     10  normal
# 5         6 2015-02-21 11:24:43    Kelly  Kpushup     20     10  normal
# 6         6 2015-02-28 14:12:17    Kelly  Kpushup     20     10  normal
# 7         6 2015-02-28 14:13:46    Kelly   pushup     20     10  normal
# 8         6 2015-03-03 08:11:21    Kelly   pushup     20     10  normal
# 9         6 2015-03-03 08:09:39    Kelly   pushup     20     10  normal
# 10        6 2015-03-04 08:04:10    Kelly   pushup     20     10  narrow
# 11        6 2015-03-04 08:05:28    Kelly  Kpushup     20     10  normal
# 12        7 2015-02-16 17:18:38     Josh   pushup     10     10  normal
# 13        7 2015-02-16 17:20:25     Josh   pushup     10     10  normal
# 14        7 2015-03-01 09:53:05     Josh   pushup     20     10  normal
# 15        7 2015-03-01 09:53:39     Josh   pushup     20     10  normal
# 16        7 2015-03-01 17:30:48     Josh   pushup     20     10  narrow
# 17        7 2015-03-03 19:56:55     Josh   pushup     20     20  normal
# 18        7 2015-03-03 19:57:56     Josh   pushup     20     10  normal
# 19        8 2015-02-26 20:00:15    Benji   pushup     20     10  normal
# 20        9 2015-02-26 19:56:20  Arielle  Kpushup     20     10  normal
# 21       10 2015-02-26 19:53:19  JustinF   pushup     20     10  narrow
# 22       11 2015-02-27 20:26:10      Wei   pushup     20     10  inward
# 23       12 2015-02-27 20:20:03    Jared   pushup     20     10  narrow
# 24       13 2015-02-27 20:21:57    Molly   pushup     20     10  normal
# 25       14 2015-02-27 17:08:09   Warren   pushup     20     20  normal
# 26       14 2015-02-27 17:07:32   Warren   pushup     20     20  normal
# 27       15 2015-02-27 17:02:15  Clayton   pushup     20     10  normal
# 28       16 2015-02-27 16:59:47  Chapman   pushup     20     10  narrow
# 29       17 2015-02-27 16:57:09    Miles   pushup     20     10  normal
# 30       18 2015-02-27 16:53:56     Zack   pushup     20     10  normal
# 31       19 2015-02-27 16:45:36    Chris   pushup     20     10  normal
# 32       20 2015-02-28 15:59:20   Martin   pushup     20     10  normal
# 33       21 2015-03-01 11:11:36     Beau   pushup     20     10  narrow
# 34       21 2015-03-01 11:13:22     Beau   pushup     20     10  normal
# 35       21 2015-03-01 11:13:51     Beau   pushup     20     10  inward
# 36       22 2015-03-01 20:03:15    Tracy  Kpushup     20     10  normal
# 37       22 2015-03-01 20:03:47    Tracy  Kpushup     20     10  narrow
# 38       23 2015-03-01 20:10:12    Rocky   pushup     20     10  normal
# 39       23 2015-03-01 20:10:35    Rocky   pushup     20     10  narrow
# 40       24 2015-03-03 19:42:06    Katie   pushup     20     10  normal
# 41       24 2015-03-03 19:42:47    Katie   pushup     20     10  narrow
#
#     height (inches)  female       form  Pcount   avg_amp   avg_dur
# 0              66.0       1         ok      10  0.218505  2.327778
# 1              64.0       1         ok      10  0.288764  2.344444
# 2              70.0       0       good      10  0.626951  1.300000
# 3              70.0       0       good      10  0.537845  1.172222
# 4              78.0       0       good      10  0.534514  1.322222
# 5              65.0       1       good      10  0.296989  2.605556
# 6              65.0       1       good      10  0.330195  2.766667
# 7              65.0       1         ok      10  0.274525  2.333333
# 8              65.0       1         ok      11  0.284956  2.415000
# 9              65.0       1         ok      11  0.269398  2.525000
# 10             65.0       1         ok       3  0.180306  5.100000
# 11             65.0       1  excellent      10  0.317760  2.788889
# 12             68.0       0  excellent      10  0.563424  1.677778
# 13             68.0       0         ok      10  0.460902  1.522222
# 14             68.0       0  excellent      10  0.548021  1.122222
# 15             68.0       0       good      10  0.478511  2.111111
# 16             68.0       0       good      10  0.550529  1.933333
# 17             68.0       0  excellent      20  0.518329  1.389474
# 18             68.0       0  excellent       9  0.566444  1.456250
# 19             72.5       0       good      10  0.425676  1.588889
# 20             64.0       1       good      10  0.388821  1.427778
# 21             73.0       0       good      10  0.486974  1.094444
# 22             67.0       0       good      10  0.501311  1.561111
# 23             71.0       0         ok      10  0.476828  0.833333
# 24             67.0       1       good      10  0.440371  1.505556
# 25             72.0       0         ok      20  0.390557  0.834211
# 26             72.0       0       good      20  0.526549  1.171053
# 27             72.0       0         ok      10  0.458803  1.027778
# 28             72.0       0  excellent      10  0.591871  1.322222
# 29             69.0       0       good      10  0.416513  1.494444
# 30             70.0       0       good      10  0.428837  2.527778
# 31             72.0       0         ok      10  0.324037  0.833333
# 32             75.0       0         ok      10  0.638048  0.938889
# 33             76.0       0  excellent      10  0.773578  1.761111
# 34             76.0       0  excellent      10  0.735598  1.133333
# 35             76.0       0  excellent      10  0.654950  1.144444
# 36             65.0       1       good      10  0.530398  1.538889
# 37             65.0       1       good      10  0.438401  2.055556
# 38             70.0       0  excellent      10  0.468986  1.055556
# 39             70.0       0  excellent      10  0.414444  1.111111
# 40             62.0       1       good      10  0.418517  1.683333
# 41             62.0       1         ok      10  0.325350  1.622222

# %%
## Expert level samples ##
#df = pd.read_csv('../data/sensor/2015-03-01_11-13-22.csv')
#sample = 'Beau_normal'
#df = pd.read_csv('../data/sensor/2015-03-01_11-11-36.csv')
#sample = 'Beau_narrow'
#df = pd.read_csv('../data/sensor/2015-03-01_11-13-51.csv')
#sample = 'Beau_inward'

## Read in one sample to process and plot ##
df = pd.read_csv('../data/sensor/2015-03-03_19-56-55.csv')
sample = 'Josh_Rnormal'

freq = 20.0
female = 0
numeric_features = ['motionUserAccelerationX', 'motionUserAccelerationY', 'motionUserAccelerationZ',
                    'motionRotationRateX', 'motionRotationRateY', 'motionRotationRateZ',
                    'accelerometerAccelerationX','accelerometerAccelerationY','accelerometerAccelerationZ',
                    'gyroRotationX','gyroRotationY','gyroRotationZ','motionYaw','motionRoll','motionPitch',
                    'motionQuaternionX','motionQuaternionY','motionQuaternionZ','motionQuaternionW']
df_num = df[numeric_features]

# %% [markdown]
# ### Plot the raw data

# %%
gr.plot1_acceleration(df_num, freq, sample)
gr.plot1_gyro(df_num, freq, sample)
gr.plot1_motion(df_num, freq, sample)
gr.plot1_quaternion(df_num, freq, sample)

# %% [markdown]
# ### Bandpass filter the data

# %%
lowcut = 0.5
highcut =2.0
order = 1 # Making the order higher messes up the beginning of the reps, keep it 1
df_filt = filter_features(df_num, numeric_features, lowcut, highcut, freq, order)
# Plot
gr.plot_bandpass(df_num, df_filt, freq, lowcut, highcut, sample)

# %% [markdown]
# ### Pushup identification and counting algorithm

# %%
# Look at correlation between features
rolling_window = 30
correls = pd.rolling_corr(df_filt, rolling_window)
# Plot
gr.plot_corr(df_filt, correls, freq, sample)

# %%
# Filter based on feature amplitudes
cond1 = np.abs(correls.ix[:, 'accelerometerAccelerationX', 'accelerometerAccelerationY']) > 0.6
cond2 = (np.abs(correls.ix[:, 'motionQuaternionY', 'motionQuaternionW'])+
         np.abs(correls.ix[:, 'motionQuaternionX', 'motionQuaternionY'])+
         np.abs(correls.ix[:, 'motionQuaternionY', 'motionQuaternionZ'])+
         np.abs(correls.ix[:, 'gyroRotationX', 'gyroRotationZ'])) > 2.5
# Trim the beginning 2.5 seconds and last 1 seconds of record
cond3 = df_filt.index > int(freq*3) 
cond4 = df_filt.index < (df_filt.shape[0] - int(freq)) 

# Pushup repetition window
#pushup_window = df_filt[cond1 & cond2 & cond3 & cond4].index
pushup_window = df_filt[cond3 & cond4].index

## Count the number of repetitions ##
# Peak parameters
mph=(0.2 - 0.025*female) # minimum peak height
mpd=0.5*freq + 0.25*freq*female # minimum peak separation distance
feature = 'motionPitch'
peakind, count = count_peaks(df_filt, pushup_window, feature, mph, mpd, freq)
# Plot
gr.plot_pushups(df_filt, pushup_window, peakind, feature, freq, sample)
print 'Number of repetitions:',count
# Out:
# Number of repetitions: 20
