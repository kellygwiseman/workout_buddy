# %%
import sys
sys.path.append(r'../code')
from dtw import *
import pandas as pd
import numpy as np
import graphs as gr
from filter import filter_features
import detect_peaks as dp
from matplotlib import rcParams
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn import metrics
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
######## Load data info #########
info = pd.read_csv('../data/pushup_info.csv', skipinitialspace=True)
info['file'] = info['timestamp'].copy()
info['timestamp'] = pd.to_datetime(info['timestamp'],format='%Y-%m-%d_%H-%M-%S')

######## Choose Data #########
# All
data_processed = info.copy()
data_processed.drop(['phone','comments'], axis=1, inplace=True)

# 10 count
#data_processed = info.copy()
#cond = data_processed['count'] == 10
#data_processed = data_processed[cond]
#data_processed.reset_index(inplace=True)
#data_processed.drop(['phone','comments','index'], axis=1, inplace=True)

# Normal stance samples
#data_processed = info.copy()
#cond1 = data_processed['stance'] == 'normal'
#cond2 = data_processed['hertz'] == 20
#data_processed = data_processed[cond1&cond2]
#data_processed.reset_index()
#data_processed.drop(['phone','comments'], axis=1, inplace=True)

# Narrow stance samples
#data_processed = info.copy()
#cond1 = data_processed['stance'] == 'narrow'
#cond2 = data_processed['hertz'] == 20
#data_processed = data_processed[cond1&cond2]
#data_processed.reset_index()
#data_processed.drop(['phone','comments'], axis=1, inplace=True)

# add columns
label = data_processed.pop('form')
label = label.map({'excellent':1, 'good':1,'ok':0})
label_arr = np.array(label)
data_processed.head(40)
# Out:
#     user_id           timestamp     name exercise  hertz  count  stance  \
# 0         1 2015-02-21 12:35:35     Tali   pushup     20     10  normal
# 1         2 2015-02-21 18:55:31     Jess   pushup     20     10  normal
# 2         3 2015-02-21 18:57:33      Sam   pushup     20     10  normal
# 3         4 2015-02-21 18:59:09     Nick   pushup     20     10  normal
# 4         5 2015-02-21 19:00:14  JustinS   pushup     20     10  normal
# 5         6 2015-02-21 11:24:43    Kelly  Kpushup     20     10  normal
# 6         6 2015-02-28 14:12:17    Kelly  Kpushup     20     10  normal
# 7         6 2015-02-28 14:13:46    Kelly   pushup     20     10  normal
# 8         6 2015-03-03 08:09:39    Kelly   pushup     20     10  normal
# 9         6 2015-03-03 08:11:21    Kelly   pushup     20     10  normal
# 10        6 2015-03-04 08:04:10    Kelly   pushup     20     10  narrow
# 11        6 2015-03-04 08:05:28    Kelly  Kpushup     20     10  normal
# ...

# %% [markdown]
# # Batch Process Data

# %%
# Data info
numeric_features = ['motionUserAccelerationX', 'motionUserAccelerationY', 'motionUserAccelerationZ',
                    'motionRotationRateX', 'motionRotationRateY', 'motionRotationRateZ',
                    'accelerometerAccelerationX','accelerometerAccelerationY','accelerometerAccelerationZ',
                    'gyroRotationX','gyroRotationY','gyroRotationZ','motionYaw','motionRoll','motionPitch',
                    'motionQuaternionX','motionQuaternionY','motionQuaternionZ','motionQuaternionW']

# Initialize time series feature lists to use in power spectra calculations
pitch_one_ts = []
accY_one_ts = []
accZ_one_ts = []
quatY_one_ts = []

# Iterate through all the samples
for i in xrange(data_processed.shape[0]):
    df = pd.read_csv('../data/sensor/'+ data_processed.loc[i,'file'] + '.csv')
    #print '../data/sensor/'+data_processed.loc[i,'file']+'.csv'
    sample = data_processed.loc[i,'name'] + '_' + data_processed.loc[i,'stance']
    female = data_processed.loc[i,'female']
    freq = float(data_processed.loc[i,'hertz'])
    df_num = df[numeric_features]
    
    ## Filter the data to separate the noise from the pushup signal ##
    # Bandpass filter
    lowcut = 0.5
    highcut = 2.0
    order = 1
    df_filt = filter_features(df_num, numeric_features, lowcut, highcut, freq, order)
    
    # Look at feature correlations
    rolling_window = 30
    correls = pd.rolling_corr(df_filt, rolling_window)
    
    # Filter based on feature amplitudes
    cond1 = np.abs(correls.ix[:, 'accelerometerAccelerationX', 'accelerometerAccelerationY']) > 0.6
    cond2 = (np.abs(correls.ix[:, 'motionQuaternionY', 'motionQuaternionW'])+
             np.abs(correls.ix[:, 'motionQuaternionX', 'motionQuaternionY'])+
             np.abs(correls.ix[:, 'motionQuaternionY', 'motionQuaternionZ'])+
             np.abs(correls.ix[:, 'gyroRotationX', 'gyroRotationZ'])) > 2.5
    # Trim the beginning 2.5 seconds and last 1 seconds of record
    cond3 = df_filt.index > int(freq*2.5) 
    cond4 = df_filt.index < (df_filt.shape[0] - int(freq)) 
    
    # Initial pushup repetition window
    pushup_window = df_filt[cond1 & cond2 & cond3 & cond4].index
    
    ## Count the number of repetitions ##
    # Peak parameters
    mph=(0.2 - 0.025*female) # minimum peak height
    mpd=0.5*freq + 0.25*freq*female # minimum peak separation distance
    feature = 'motionPitch'
    peakind, count = dp.count_peaks(df_filt, pushup_window, feature, mph, mpd, freq)
    avg_amp = dp.average_amplitude(df_filt, peakind, pushup_window, feature, freq)
    avg_dur = dp.average_duration(peakind, count)

    # Final tight pushup repetition window
    window_ind, window_sec = dp.calculate_rep_window(peakind, pushup_window, avg_dur, freq)

    # Middle repetition window
    rep_window_ind, rep_window_sec = dp.one_rep_window(peakind, pushup_window, freq)
    
    # add one rep time series to feature lists
    rep_data = df_num.ix[rep_window_ind[0]:rep_window_ind[1]]
    pitch_one_ts.append(rep_data['motionPitch'].tolist())
    accY_one_ts.append(rep_data['accelerometerAccelerationY'].tolist())
    accZ_one_ts.append(rep_data['accelerometerAccelerationZ'].tolist())
    quatY_one_ts.append(rep_data['motionQuaternionY'].tolist())

# %%
print data_processed['avg_dur'].mean()
print data_processed['avg_amp'].mean()
# Out:
# 1.69261608883
# 0.454973891625

# %% [markdown]
# ## One Rep Analysis

# %%
avg_length = 34    
sss = StratifiedShuffleSplit(label_arr, n_iter = 5, test_size = 0.3, random_state=100)
features = ['Pitch','AccY','AccZ','QuatY']
data = [pitch_one_ts,accY_one_ts,accZ_one_ts,quatY_one_ts]
acc_list = []
prec_list = []
recall_list = []

for d in xrange(len(data)):
    # resample to average length
    X=[signal.resample(xi, avg_length) for xi in data[d]]
    # initialize rep to 0
    X = np.array([xi - xi[0] for xi in X])
    for train_index, test_index in sss:
        #print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = label_arr[train_index], label_arr[test_index]
        m = KnnDtw(n_neighbors=4, max_warping_window=10)
        m.fit(X_train, y_train)
        y_pred, proba = m.predict(X_test)
        acc = metrics.accuracy_score(y_test, y_pred)
        acc_list.append(acc)
        #print 'accuracy score for default parameters', acc
        recall = metrics.recall_score(y_test, y_pred)
        recall_list.append(recall)
        #print 'recall score for default parameters', recall
        precision = metrics.precision_score(y_test, y_pred)
        prec_list.append(precision)
        #print 'precision score for default parameters', precision
        cm = metrics.confusion_matrix(y_test, y_pred)
        print(cm)

    print 'average accuracy and std for feature', features[d], np.mean(acc_list), np.std(acc_list)
    print 'average precison and std for feature', features[d], np.mean(prec_list), np.std(prec_list)
    print 'average recall and std for feature', features[d], np.mean(recall_list), np.std(recall_list)
# Out:
# [                  0%                  ]
# [                  1%                  ]  2 of 377 complete
# [                  1%                  ]  3 of 377 complete
# [                  1%                  ]  4 of 377 complete
# [                  1%                  ]  5 of 377 complete
# [*                 2%                  ]  6 of 377 complete
# [*                 2%                  ]  7 of 377 complete
# [*                 2%                  ]  8 of 377 complete
# [*                 2%                  ]  9 of 377 complete
# [*                 3%                  ]  10 of 377 complete
# [*                 3%                  ]  11 of 377 complete
# [*                 3%                  ]  12 of 377 complete
# [*                 3%                  ]  13 of 377 complete
# [**                4%                  ]  14 of 377 complete
# [**                4%                  ]  15 of 377 complete
# [**                4%                  ]  16 of 377 complete
# ...

# %% [markdown]
# ### Individual Rep Comparison

# %%
rep_ind = [0,23, 31,33] # for OK, GOOD, EXCELLENT
names = ['Tali', 'Jared','Tracy','Beau']
features = ['Pitch','AccY','AccZ','QuatY']
data = [pitch_one_ts,accY_one_ts,accZ_one_ts,quatY_one_ts]
avg_length = 34

for i in xrange(len(rep_ind)):
    fig = plt.figure()
    for d in xrange(len(data)):
        # resample to average length
        #X=np.array([signal.resample(xi, avg_length) for xi in data[d]])
        # initialize rep to 0
        X = np.array([xi - xi[0] for xi in data[d]])
        X_train = X[rep_ind[i]]

        f, Pxx_den = signal.periodogram(X_train, fs=freq)
        f = f.reshape((len(f),1))
        Pxx_den = Pxx_den.reshape((len(f),1))
        plt.hist(Pxx_den,bins=10,label=features[d])
        plt.xlabel('frequency [Hz]')
        plt.ylabel('PSD [amp**2/Hz]')
        plt.title(names[i]+' Power Spectra')
    plt.legend()

# %%
rep_ind = [0,23, 31,33] # for OK, GOOD, EXCELLENT
names = ['Tali', 'Jared','Tracy','Beau']
features = ['Pitch','AccY','AccZ','QuatY']
data = [pitch_one_ts,accY_one_ts,accZ_one_ts,quatY_one_ts]
avg_length = 34

for i in xrange(len(rep_ind)):
    fig = plt.figure()
    for d in xrange(len(data)):
        # resample to average length
        #X=np.array([signal.resample(xi, avg_length) for xi in data[d]])
        # initialize rep to 0
        X = np.array([xi - xi[0] for xi in data[d]])
        X_train = X[rep_ind[i]]

        plt.psd(X_train, Fs=freq, pad_to = 256,label=features[d])
        #f = f.reshape((len(f),1))
        #Pxx_den = Pxx_den.reshape((len(f),1))
        #plt.semilogy(f, Pxx_den, label=features[d])
        #plt.ylim([1e-5, 1e0])
        plt.xlabel('frequency [Hz]')
        plt.ylabel('PSD [amp**2/Hz]')
        plt.title(names[i]+' Power Spectra')
    plt.legend(loc='lower left')

# %%
#rep_ind = [(0,31),(33,31),(23,31)] # for OK, GOOD, EXCELLENT
rep_ind = [(31,0),(33,0),(23,0)] # for OK, GOOD, EXCELLENT
names = ['Beau-Tali','Tracy-Tali','Jared-Tali']
features = ['Pitch','AccY','AccZ','QuatY']
data = [pitch_one_ts,accY_one_ts,accZ_one_ts,quatY_one_ts]
avg_length = 34

for i in xrange(len(rep_ind)):
    fig = plt.figure()
    for d in xrange(len(data)):
        # resample to average length
        #X=np.array([signal.resample(xi, avg_length) for xi in data[d]])
        # initialize rep to 0
        X = np.array([xi - xi[0] for xi in data[d]])
        x = X[rep_ind[i][0]]
        y = X[rep_ind[i][1]]

        plt.csd(x, y,Fs=freq, pad_to = 256, scale_by_freq = True, label=features[d])
        plt.psd
        #f = f.reshape((len(f),1))
        #Pxx_den = Pxx_den.reshape((len(f),1))
        #plt.semilogy(f, Pxx_den, label=features[d])
        #plt.ylim([1e-5, 1e0])
        plt.xlabel('frequency [Hz]')
        plt.ylabel('PSD [amp**2/Hz]')
        plt.title(names[i]+' cross-spectral density')
    plt.legend()

# %%
from psd import psd
rep_ind = [0,23, 31,33] # for OK, GOOD, EXCELLENT
names = ['Tali', 'Jared','Tracy','Beau']
features = ['accY']
data = [accY_one_ts]

for i in xrange(len(rep_ind)):
    fig = plt.figure()
    for d in xrange(len(data)):
        # resample to average length
        #X=np.array([signal.resample(xi, avg_length) for xi in data[d]])
        # initialize rep to 0
        X = np.array([xi - xi[0] for xi in data[d]])
        X_train = X[rep_ind[i]]
        fp, mf, fmax, Ptot, F, P = psd(X_train, fs=freq, scales='linear', units='g')

# %%
mf
# Out:
# 1.6625510253254097
